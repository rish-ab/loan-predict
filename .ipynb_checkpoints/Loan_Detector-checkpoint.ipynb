# %% [markdown]
# # Loan Detector

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
import sklearn.preprocessing

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Data

# %%
df_risk = pd.read_csv('raw_data/Loan_default.csv')
df_AM = pd.read_csv('raw_data/Loan_approval.csv')
df_credit = pd.read_csv('raw_data/UCI.csv')

df_risk.info()
df_AM.info()
df_credit.info()

df_risk.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
#  16  HasCoSigner     255347 non-null  object
#  17  Default         255347 non-null  int64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 35.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              50000 non-null  object
#  1   age                      50000 non-null  int64
#  2   occupation_status        50000 non-null  object
#  3   years_employed           50000 non-null  float64
#  4   annual_income            50000 non-null  int64
#  5   credit_score             50000 non-null  int64
#  6   credit_history_years     50000 non-null  float64
#  7   savings_assets           50000 non-null  int64
#  8   current_debt             50000 non-null  int64
#  9   defaults_on_file         50000 non-null  int64
#  10  delinquencies_last_2yrs  50000 non-null  int64
#  11  derogatory_marks         50000 non-null  int64
#  12  product_type             50000 non-null  object
#  13  loan_intent              50000 non-null  object
#  14  loan_amount              50000 non-null  int64
#  15  interest_rate            50000 non-null  float64
#  16  debt_to_income_ratio     50000 non-null  float64
#  17  loan_to_income_ratio     50000 non-null  float64
#  18  payment_to_income_ratio  50000 non-null  float64
#  19  loan_status              50000 non-null  int64
# dtypes: float64(6), int64(10), object(4)
# memory usage: 7.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
#  13  BILL_AMT2                   30000 non-null  float64
#  14  BILL_AMT3                   30000 non-null  float64
#  15  BILL_AMT4                   30000 non-null  float64
#  16  BILL_AMT5                   30000 non-null  float64
#  17  BILL_AMT6                   30000 non-null  float64
#  18  PAY_AMT1                    30000 non-null  float64
#  19  PAY_AMT2                    30000 non-null  float64
#  20  PAY_AMT3                    30000 non-null  float64
#  21  PAY_AMT4                    30000 non-null  float64
#  22  PAY_AMT5                    30000 non-null  float64
#  23  PAY_AMT6                    30000 non-null  float64
#  24  default.payment.next.month  30000 non-null  int64
# dtypes: float64(13), int64(12)
# memory usage: 5.7 MB
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# 2               3         21.17        24      0.31     Master's
# 3               3          7.07        24      0.23  High School
# 4               4          6.51        48      0.73   Bachelor's
#
#   EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0      Full-time      Divorced         Yes           Yes       Other
# 1      Full-time       Married          No            No       Other
# 2     Unemployed      Divorced         Yes           Yes        Auto
# 3      Full-time       Married          No            No    Business
# 4     Unemployed      Divorced          No           Yes        Auto
#
#   HasCoSigner  Default
# 0         Yes        0
# 1         Yes        0
# 2          No        1
# 3          No        0
# 4          No        0

# %% [markdown]
# ## Cleaning Data

# %%
df_risk['LoanPurpose'].unique()
# Out:
# array(['Other', 'Auto', 'Business', 'Home', 'Education'], dtype=object)

# %%
# 1. One-Hot Encoding for LoanPurpose
df_risk = pd.get_dummies(df_risk, columns=['LoanPurpose'], dtype=int)

# 2. Ordinal Mappings
mar_map = {'Single': 0, 'Married': 1, 'Divorced': 2}
df_risk['MaritalStatusCode'] = df_risk['MaritalStatus'].map(mar_map)

edu_map = {"High School": 0, "Bachelor's": 1, "Master's": 2, "PhD": 3}
df_risk['EducationCode'] = df_risk['Education'].map(edu_map)

Emp_map = {"Unemployed": 0, "Part-time": 1, "Self-employed": 2, "Full-time": 3}
df_risk['EmploymentCode'] = df_risk['EmploymentType'].map(Emp_map)

# 3. Binary Encoding via .cat.codes
df_risk['HasMortgageCode'] = df_risk['HasMortgage'].astype('category').cat.codes
df_risk['HasDependentsCode'] = df_risk['HasDependents'].astype('category').cat.codes
df_risk['HasCoSignerCode'] = df_risk['HasCoSigner'].astype('category').cat.codes

# 4. Drop original string columns
df_risk.drop(columns=['MaritalStatus', 'Education', 'EmploymentType', 'HasMortgage', 'HasDependents', 'HasCoSigner'], inplace=True)

df_risk['LTI'] = df_risk['LoanAmount']/df_risk['Income']
df_risk['MonthlyDebtRatio'] = (df_risk['Income']/12)*df_risk['DTIRatio']
df_risk['InterestBurden'] = df_risk['LoanAmount'] * (df_risk['InterestRate']/100)

df_risk.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 # 1. One-Hot Encoding for LoanPurpose
# ----> 2 df_risk = pd.get_dummies(df_risk, columns=['LoanPurpose'], dtype=int)
#       4 # 2. Ordinal Mappings
#       5 mar_map = {'Single': 0, 'Married': 1, 'Divorced': 2}
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/reshape/encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167     raise TypeError("Input must be a list-like for parameter `columns`")
#     168 else:
# --> 169     data_to_encode = data[columns]
#     171 # validate prefixes and separator to avoid silently dropping cols
#     172 def check_len(item, name: str):
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/datasci/lib/python3.11/site-packages/pandas/core/indexes/base.py:6248, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6246 if nmissing:
#    6247     if nmissing == len(indexer):
# -> 6248         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6251     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['LoanPurpose'], dtype='object')] are in the [columns]"

# %%
df_risk.isnull().sum()
# Out:
# LoanID                   0
# Age                      0
# Income                   0
# LoanAmount               0
# CreditScore              0
# MonthsEmployed           0
# NumCreditLines           0
# InterestRate             0
# LoanTerm                 0
# DTIRatio                 0
# Default                  0
# LoanPurpose_Auto         0
# LoanPurpose_Business     0
# LoanPurpose_Education    0
# LoanPurpose_Home         0
# LoanPurpose_Other        0
# MaritalStatusCode        0
# EducationCode            0
# EmploymentCode           0
# HasMortgageCode          0
# HasDependentsCode        0
# HasCoSignerCode          0
# dtype: int64

# %% [markdown]
# ## General Analysis

# %%
df_risk.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# 25%         30.000000        2.000000       7.770000      24.000000
# 50%         60.000000        2.000000      13.460000      36.000000
# 75%         90.000000        3.000000      19.250000      48.000000
# max        119.000000        4.000000      25.000000      60.000000
#
#             DTIRatio        Default  ...  LoanPurpose_Business  \
# count  255347.000000  255347.000000  ...         255347.000000
# mean        0.500212       0.116128  ...              0.200895
# std         0.230917       0.320379  ...              0.400671
# min         0.100000       0.000000  ...              0.000000
# 25%         0.300000       0.000000  ...              0.000000
# 50%         0.500000       0.000000  ...              0.000000
# 75%         0.700000       0.000000  ...              0.000000
# max         0.900000       1.000000  ...              1.000000
#
#        LoanPurpose_Education  LoanPurpose_Home  LoanPurpose_Other  \
# count          255347.000000     255347.000000      255347.000000
# mean                0.199748          0.200848           0.199391
# std                 0.399812          0.400636           0.399544
# min                 0.000000          0.000000           0.000000
# 25%                 0.000000          0.000000           0.000000
# 50%                 0.000000          0.000000           0.000000
# 75%                 0.000000          0.000000           0.000000
# max                 1.000000          1.000000           1.000000
#
#        MaritalStatusCode  EducationCode  EmploymentCode  HasMortgageCode  \
# count      255347.000000  255347.000000   255347.000000    255347.000000
# mean            1.000082       1.496235        1.498122         0.500014
# std             0.816051       1.117212        1.117357         0.500001
# min             0.000000       0.000000        0.000000         0.000000
# 25%             0.000000       0.000000        1.000000         0.000000
# 50%             1.000000       1.000000        1.000000         1.000000
# 75%             2.000000       2.000000        2.000000         1.000000
# max             2.000000       3.000000        3.000000         1.000000
#
#        HasDependentsCode  HasCoSignerCode
# count      255347.000000    255347.000000
# mean            0.500268         0.500108
# std             0.500001         0.500001
# min             0.000000         0.000000
# 25%             0.000000         0.000000
# 50%             1.000000         1.000000
# 75%             1.000000         1.000000
# max             1.000000         1.000000
#
# [8 rows x 21 columns]

# %%
df_risk.groupby('CreditScore').agg({'CreditScore': 'count'})
# Out:
#              CreditScore
# CreditScore
# 300                  484
# 301                  460
# 302                  451
# 303                  489
# 304                  456
# ...                  ...
# 845                  438
# 846                  437
# 847                  450
# 848                  463
# 849                  496
#
# [550 rows x 1 columns]

# %% [markdown]
# ## Correlation Matrix

# %%
df_risk.corr(numeric_only=True)
corr_matrix = df_risk.corr(numeric_only=True)
print(corr_matrix)
# Out:
#                             Age    Income  LoanAmount  CreditScore  \
# Age                    1.000000 -0.001244   -0.002213    -0.000548
# Income                -0.001244  1.000000   -0.000865    -0.001430
# LoanAmount            -0.002213 -0.000865    1.000000     0.001261
# CreditScore           -0.000548 -0.001430    0.001261     1.000000
# MonthsEmployed        -0.000341  0.002675    0.002817     0.000613
# NumCreditLines        -0.000890 -0.002016    0.000794     0.000016
# InterestRate          -0.001127 -0.002303   -0.002291     0.000436
# LoanTerm               0.000263 -0.000998    0.002538     0.001130
# DTIRatio              -0.004689  0.000205    0.001122    -0.001039
# Default               -0.167783 -0.099119    0.086659    -0.034166
# LoanPurpose_Auto       0.001604  0.000115    0.001964     0.000978
# LoanPurpose_Business  -0.003104  0.005124   -0.003093    -0.000638
# LoanPurpose_Education -0.002300 -0.003610    0.000472    -0.003306
# LoanPurpose_Home      -0.000474 -0.001250    0.000308     0.002513
# LoanPurpose_Other      0.004286 -0.000388    0.000358     0.000451
# MaritalStatusCode      0.002187 -0.000637    0.000771     0.003218
# EducationCode         -0.000848  0.000681    0.002540    -0.000800
# EmploymentCode         0.000213  0.005479   -0.002717    -0.002680
# HasMortgageCode        0.000035 -0.000945   -0.000801     0.001728
# HasDependentsCode      0.000710 -0.001570    0.000139    -0.003018
# HasCoSignerCode       -0.002918 -0.003524   -0.001848    -0.002755
#
#                        MonthsEmployed  NumCreditLines  InterestRate  LoanTerm  \
# Age                         -0.000341       -0.000890     -0.001127  0.000263
# Income                       0.002675       -0.002016     -0.002303 -0.000998
# LoanAmount                   0.002817        0.000794     -0.002291  0.002538
# CreditScore                  0.000613        0.000016      0.000436  0.001130
# MonthsEmployed               1.000000        0.001267      0.000096 -0.001166
# NumCreditLines               0.001267        1.000000     -0.000297 -0.000226
# InterestRate                 0.000096       -0.000297      1.000000  0.000892
# LoanTerm                    -0.001166       -0.000226      0.000892  1.000000
# DTIRatio                     0.001765       -0.000586      0.000575  0.002273
# Default                     -0.097374        0.028330      0.131273  0.000545
# LoanPurpose_Auto             0.001570       -0.002157     -0.001922 -0.000636
# LoanPurpose_Business         0.001518        0.000988     -0.001029 -0.003032
# LoanPurpose_Education        0.001159        0.002040      0.001493  0.000942
# LoanPurpose_Home            -0.004033        0.000366      0.002580 -0.000316
# LoanPurpose_Other           -0.000208       -0.001244     -0.001128  0.003051
# MaritalStatusCode            0.000095        0.000664      0.005079  0.001042
# EducationCode               -0.001147        0.001531      0.003417 -0.001421
# EmploymentCode              -0.000831        0.000004     -0.001030 -0.002043
# HasMortgageCode              0.000210       -0.001744     -0.000424  0.001775
# HasDependentsCode            0.001450       -0.001895     -0.000243  0.002417
# HasCoSignerCode              0.001045        0.002105     -0.003991 -0.001166
#
#                        DTIRatio   Default  ...  LoanPurpose_Business  \
# Age                   -0.004689 -0.167783  ...             -0.003104
# Income                 0.000205 -0.099119  ...              0.005124
# LoanAmount             0.001122  0.086659  ...             -0.003093
# CreditScore           -0.001039 -0.034166  ...             -0.000638
# MonthsEmployed         0.001765 -0.097374  ...              0.001518
# NumCreditLines        -0.000586  0.028330  ...              0.000988
# InterestRate           0.000575  0.131273  ...             -0.001029
# LoanTerm               0.002273  0.000545  ...             -0.003032
# DTIRatio               1.000000  0.019236  ...              0.000481
# Default                0.019236  1.000000  ...              0.011162
# LoanPurpose_Auto       0.002177  0.004181  ...             -0.250007
# LoanPurpose_Business   0.000481  0.011162  ...              1.000000
# LoanPurpose_Education  0.002513  0.003512  ...             -0.250502
# LoanPurpose_Home      -0.001672 -0.021564  ...             -0.251364
# LoanPurpose_Other     -0.003497  0.002737  ...             -0.250222
# MaritalStatusCode     -0.004492  0.007902  ...              0.001770
# EducationCode          0.001947 -0.028282  ...             -0.000191
# EmploymentCode         0.000101 -0.044534  ...             -0.001598
# HasMortgageCode        0.000231 -0.022856  ...             -0.002223
# HasDependentsCode      0.001492 -0.034678  ...              0.003230
# HasCoSignerCode        0.000373 -0.039109  ...             -0.002395
#
#                        LoanPurpose_Education  LoanPurpose_Home  \
# Age                                -0.002300         -0.000474
# Income                             -0.003610         -0.001250
# LoanAmount                          0.000472          0.000308
# CreditScore                        -0.003306          0.002513
# MonthsEmployed                      0.001159         -0.004033
# NumCreditLines                      0.002040          0.000366
# InterestRate                        0.001493          0.002580
# LoanTerm                            0.000942         -0.000316
# DTIRatio                            0.002513         -0.001672
# Default                             0.003512         -0.021564
# LoanPurpose_Auto                   -0.249114         -0.249971
# LoanPurpose_Business               -0.250502         -0.251364
# LoanPurpose_Education               1.000000         -0.250465
# LoanPurpose_Home                   -0.250465          1.000000
# LoanPurpose_Other                  -0.249328         -0.250186
# MaritalStatusCode                   0.000766          0.000572
# EducationCode                      -0.000355         -0.000016
# EmploymentCode                     -0.000787          0.000388
# HasMortgageCode                     0.001407         -0.001773
# HasDependentsCode                   0.000721         -0.000249
# HasCoSignerCode                     0.000549          0.000674
#
#                        LoanPurpose_Other  MaritalStatusCode  EducationCode  \
# Age                             0.004286           0.002187      -0.000848
# Income                         -0.000388          -0.000637       0.000681
# LoanAmount                      0.000358           0.000771       0.002540
# CreditScore                     0.000451           0.003218      -0.000800
# MonthsEmployed                 -0.000208           0.000095      -0.001147
# NumCreditLines                 -0.001244           0.000664       0.001531
# InterestRate                   -0.001128           0.005079       0.003417
# LoanTerm                        0.003051           0.001042      -0.001421
# DTIRatio                       -0.003497          -0.004492       0.001947
# Default                         0.002737           0.007902      -0.028282
# LoanPurpose_Auto               -0.248836          -0.000591       0.002128
# LoanPurpose_Business           -0.250222           0.001770      -0.000191
# LoanPurpose_Education          -0.249328           0.000766      -0.000355
# LoanPurpose_Home               -0.250186           0.000572      -0.000016
# LoanPurpose_Other               1.000000          -0.002525      -0.001564
# MaritalStatusCode              -0.002525           1.000000       0.001540
# EducationCode                  -0.001564           0.001540       1.000000
# EmploymentCode                  0.000330           0.001806      -0.000618
# HasMortgageCode                -0.000719           0.000408       0.001965
# HasDependentsCode              -0.004306           0.000437       0.000056
# HasCoSignerCode                -0.001891           0.000888       0.001692
#
#                        EmploymentCode  HasMortgageCode  HasDependentsCode  \
# Age                          0.000213         0.000035           0.000710
# Income                       0.005479        -0.000945          -0.001570
# LoanAmount                  -0.002717        -0.000801           0.000139
# CreditScore                 -0.002680         0.001728          -0.003018
# MonthsEmployed              -0.000831         0.000210           0.001450
# NumCreditLines               0.000004        -0.001744          -0.001895
# InterestRate                -0.001030        -0.000424          -0.000243
# LoanTerm                    -0.002043         0.001775           0.002417
# DTIRatio                     0.000101         0.000231           0.001492
# Default                     -0.044534        -0.022856          -0.034678
# LoanPurpose_Auto             0.001672         0.003321           0.000595
# LoanPurpose_Business        -0.001598        -0.002223           0.003230
# LoanPurpose_Education       -0.000787         0.001407           0.000721
# LoanPurpose_Home             0.000388        -0.001773          -0.000249
# LoanPurpose_Other            0.000330        -0.000719          -0.004306
# MaritalStatusCode            0.001806         0.000408           0.000437
# EducationCode               -0.000618         0.001965           0.000056
# EmploymentCode               1.000000        -0.000258          -0.001683
# HasMortgageCode             -0.000258         1.000000           0.000067
# HasDependentsCode           -0.001683         0.000067           1.000000
# HasCoSignerCode              0.000787        -0.003529           0.001602
#
#                        HasCoSignerCode
# Age                          -0.002918
# Income                       -0.003524
# LoanAmount                   -0.001848
# CreditScore                  -0.002755
# MonthsEmployed                0.001045
# NumCreditLines                0.002105
# InterestRate                 -0.003991
# LoanTerm                     -0.001166
# DTIRatio                      0.000373
# Default                      -0.039109
# LoanPurpose_Auto              0.003070
# LoanPurpose_Business         -0.002395
# LoanPurpose_Education         0.000549
# LoanPurpose_Home              0.000674
# LoanPurpose_Other            -0.001891
# MaritalStatusCode             0.000888
# EducationCode                 0.001692
# EmploymentCode                0.000787
# HasMortgageCode              -0.003529
# HasDependentsCode             0.001602
# HasCoSignerCode               1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(24,12))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

sns.heatmap(corr_matrix, mask=mask, annot=True)
plt.title("Feature Correlation Matrix with Loan Default", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation just on Loan Defaults

# %%
default_corr = corr_matrix["Default"].drop("Default").sort_values()
print(default_corr)
# Out:
# Age                     -0.167783
# Income                  -0.099119
# MonthsEmployed          -0.097374
# EmploymentCode          -0.044534
# HasCoSignerCode         -0.039109
# HasDependentsCode       -0.034678
# CreditScore             -0.034166
# EducationCode           -0.028282
# HasMortgageCode         -0.022856
# LoanPurpose_Home        -0.021564
# LoanTerm                 0.000545
# LoanPurpose_Other        0.002737
# LoanPurpose_Education    0.003512
# LoanPurpose_Auto         0.004181
# MaritalStatusCode        0.007902
# LoanPurpose_Business     0.011162
# DTIRatio                 0.019236
# NumCreditLines           0.028330
# LoanAmount               0.086659
# InterestRate             0.131273
# Name: Default, dtype: float64

# %%
plt.figure(figsize=(12, 7))
colors = ["#d73027" if x < 0 else "#4575b4" for x in default_corr]
default_corr.plot(kind="barh", color=colors)
plt.title("Linear Correlation of Features with Loan Default", fontsize=13)
plt.xlabel("Pearson Correlation Coefficient")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Covariance Matrix

# %%
cov_matrix=df_risk.cov(numeric_only=True)
print(cov_matrix)
# Out:
#                                Age        Income    LoanAmount   CreditScore  \
# Age                     224.707847 -7.266333e+02 -2.349755e+03     -1.305749
# Income                 -726.633252  1.518116e+09 -2.388444e+06  -8856.434459
# LoanAmount            -2349.755323 -2.388444e+06  5.018406e+09  14197.937653
# CreditScore              -1.305749 -8.856434e+03  1.419794e+04  25250.438819
# MonthsEmployed           -0.177287  3.610577e+03  6.912970e+03      3.373593
# NumCreditLines           -0.014899 -8.775894e+01  6.286151e+01      0.002847
# InterestRate             -0.112154 -5.956101e+02 -1.077125e+03      0.459933
# LoanTerm                  0.066988 -6.599837e+02  3.050938e+03      3.048022
# DTIRatio                 -0.016232  1.848896e+00  1.836089e+01     -0.038134
# Default                  -0.805790 -1.237303e+03  1.966808e+03     -1.739399
# LoanPurpose_Auto          0.009599  1.791048e+00  5.556254e+01      0.062040
# LoanPurpose_Business     -0.018646  7.999001e+01 -8.780323e+01     -0.040629
# LoanPurpose_Education    -0.013782 -5.624092e+01  1.337463e+01     -0.210036
# LoanPurpose_Home         -0.002844 -1.950467e+01  8.740416e+00      0.160009
# LoanPurpose_Other         0.025672 -6.035478e+00  1.012564e+01      0.028616
# MaritalStatusCode         0.026754 -2.025988e+01  4.454619e+01      0.417243
# EducationCode            -0.014202  2.965986e+01  2.010563e+02     -0.141936
# EmploymentCode            0.003569  2.385453e+02 -2.150627e+02     -0.475892
# HasMortgageCode           0.000261 -1.840259e+01 -2.836798e+01      0.137324
# HasDependentsCode         0.005324 -3.057880e+01  4.929730e+00     -0.239781
# HasCoSignerCode          -0.021869 -6.864397e+01 -6.545581e+01     -0.218884
#
#                        MonthsEmployed  NumCreditLines  InterestRate  \
# Age                         -0.177287       -0.014899     -0.112154
# Income                    3610.576524      -87.758937   -595.610079
# LoanAmount                6912.970233       62.861514  -1077.124510
# CreditScore                  3.373593        0.002847      0.459933
# MonthsEmployed            1200.163476        0.049034      0.021973
# NumCreditLines               0.049034        1.247728     -0.002199
# InterestRate                 0.021973       -0.002199     44.042377
# LoanTerm                    -0.685499       -0.004280      0.100454
# DTIRatio                     0.014117       -0.000151      0.000882
# Default                     -1.080754        0.010138      0.279110
# LoanPurpose_Auto             0.021726       -0.000962     -0.005093
# LoanPurpose_Business         0.021064        0.000442     -0.002737
# LoanPurpose_Education        0.016059        0.000911      0.003961
# LoanPurpose_Home            -0.055974        0.000164      0.006860
# LoanPurpose_Other           -0.002875       -0.000555     -0.002992
# MaritalStatusCode            0.002697        0.000605      0.027509
# EducationCode               -0.044386        0.001910      0.025334
# EmploymentCode              -0.032149        0.000005     -0.007640
# HasMortgageCode              0.003639       -0.000974     -0.001408
# HasDependentsCode            0.025111       -0.001059     -0.000807
# HasCoSignerCode              0.018105        0.001176     -0.013242
#
#                           LoanTerm   DTIRatio      Default  ...  \
# Age                       0.066988  -0.016232    -0.805790  ...
# Income                 -659.983685   1.848896 -1237.302790  ...
# LoanAmount             3050.937995  18.360894  1966.807516  ...
# CreditScore               3.048022  -0.038134    -1.739399  ...
# MonthsEmployed           -0.685499   0.014117    -1.080754  ...
# NumCreditLines           -0.004280  -0.000151     0.010138  ...
# InterestRate              0.100454   0.000882     0.279110  ...
# LoanTerm                287.958162   0.008907     0.002961  ...
# DTIRatio                  0.008907   0.053322     0.001423  ...
# Default                   0.002961   0.001423     0.102643  ...
# LoanPurpose_Auto         -0.004310   0.000201     0.000535  ...
# LoanPurpose_Business     -0.020616   0.000044     0.001433  ...
# LoanPurpose_Education     0.006388   0.000232     0.000450  ...
# LoanPurpose_Home         -0.002146  -0.000155    -0.002768  ...
# LoanPurpose_Other         0.020684  -0.000323     0.000350  ...
# MaritalStatusCode         0.014425  -0.000847     0.002066  ...
# EducationCode            -0.026948   0.000502    -0.010123  ...
# EmploymentCode           -0.038746   0.000026    -0.015942  ...
# HasMortgageCode           0.015062   0.000027    -0.003661  ...
# HasDependentsCode         0.020506   0.000172    -0.005555  ...
# HasCoSignerCode          -0.009895   0.000043    -0.006265  ...
#
#                        LoanPurpose_Business  LoanPurpose_Education  \
# Age                               -0.018646              -0.013782
# Income                            79.990013             -56.240916
# LoanAmount                       -87.803232              13.374631
# CreditScore                       -0.040629              -0.210036
# MonthsEmployed                     0.021064               0.016059
# NumCreditLines                     0.000442               0.000911
# InterestRate                      -0.002737               0.003961
# LoanTerm                          -0.020616               0.006388
# DTIRatio                           0.000044               0.000232
# Default                            0.001433               0.000450
# LoanPurpose_Auto                  -0.040002              -0.039773
# LoanPurpose_Business               0.160537              -0.040129
# LoanPurpose_Education             -0.040129               0.159849
# LoanPurpose_Home                  -0.040350              -0.040119
# LoanPurpose_Other                 -0.040057              -0.039828
# MaritalStatusCode                  0.000579               0.000250
# EducationCode                     -0.000086              -0.000158
# EmploymentCode                    -0.000715              -0.000351
# HasMortgageCode                   -0.000445               0.000281
# HasDependentsCode                  0.000647               0.000144
# HasCoSignerCode                   -0.000480               0.000110
#
#                        LoanPurpose_Home  LoanPurpose_Other  MaritalStatusCode  \
# Age                           -0.002844           0.025672           0.026754
# Income                       -19.504667          -6.035478         -20.259880
# LoanAmount                     8.740416          10.125642          44.546192
# CreditScore                    0.160009           0.028616           0.417243
# MonthsEmployed                -0.055974          -0.002875           0.002697
# NumCreditLines                 0.000164          -0.000555           0.000605
# InterestRate                   0.006860          -0.002992           0.027509
# LoanTerm                      -0.002146           0.020684           0.014425
# DTIRatio                      -0.000155          -0.000323          -0.000847
# Default                       -0.002768           0.000350           0.002066
# LoanPurpose_Auto              -0.039993          -0.039702          -0.000193
# LoanPurpose_Business          -0.040350          -0.040057           0.000579
# LoanPurpose_Education         -0.040119          -0.039828           0.000250
# LoanPurpose_Home               0.160509          -0.040048           0.000187
# LoanPurpose_Other             -0.040048           0.159635          -0.000823
# MaritalStatusCode              0.000187          -0.000823           0.665940
# EducationCode                 -0.000007          -0.000698           0.001404
# EmploymentCode                 0.000174           0.000147           0.001647
# HasMortgageCode               -0.000355          -0.000144           0.000166
# HasDependentsCode             -0.000050          -0.000860           0.000178
# HasCoSignerCode                0.000135          -0.000378           0.000362
#
#                        EducationCode  EmploymentCode  HasMortgageCode  \
# Age                        -0.014202        0.003569         0.000261
# Income                     29.659865      238.545311       -18.402591
# LoanAmount                201.056273     -215.062660       -28.367983
# CreditScore                -0.141936       -0.475892         0.137324
# MonthsEmployed             -0.044386       -0.032149         0.003639
# NumCreditLines              0.001910        0.000005        -0.000974
# InterestRate                0.025334       -0.007640        -0.001408
# LoanTerm                   -0.026948       -0.038746         0.015062
# DTIRatio                    0.000502        0.000026         0.000027
# Default                    -0.010123       -0.015942        -0.003661
# LoanPurpose_Auto            0.000950        0.000746         0.000663
# LoanPurpose_Business       -0.000086       -0.000715        -0.000445
# LoanPurpose_Education      -0.000158       -0.000351         0.000281
# LoanPurpose_Home           -0.000007        0.000174        -0.000355
# LoanPurpose_Other          -0.000698        0.000147        -0.000144
# MaritalStatusCode           0.001404        0.001647         0.000166
# EducationCode               1.248162       -0.000772         0.001098
# EmploymentCode             -0.000772        1.248486        -0.000144
# HasMortgageCode             0.001098       -0.000144         0.250001
# HasDependentsCode           0.000031       -0.000940         0.000017
# HasCoSignerCode             0.000945        0.000440        -0.000882
#
#                        HasDependentsCode  HasCoSignerCode
# Age                             0.005324        -0.021869
# Income                        -30.578798       -68.643971
# LoanAmount                      4.929730       -65.455812
# CreditScore                    -0.239781        -0.218884
# MonthsEmployed                  0.025111         0.018105
# NumCreditLines                 -0.001059         0.001176
# InterestRate                   -0.000807        -0.013242
# LoanTerm                        0.020506        -0.009895
# DTIRatio                        0.000172         0.000043
# Default                        -0.005555        -0.006265
# LoanPurpose_Auto                0.000119         0.000613
# LoanPurpose_Business            0.000647        -0.000480
# LoanPurpose_Education           0.000144         0.000110
# LoanPurpose_Home               -0.000050         0.000135
# LoanPurpose_Other              -0.000860        -0.000378
# MaritalStatusCode               0.000178         0.000362
# EducationCode                   0.000031         0.000945
# EmploymentCode                 -0.000940         0.000440
# HasMortgageCode                 0.000017        -0.000882
# HasDependentsCode               0.250001         0.000400
# HasCoSignerCode                 0.000400         0.250001
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(18,12))
mask = np.triu(np.ones_like(cov_matrix, dtype=bool))

sns.heatmap(corr_matrix, mask=mask, annot=True)
plt.title("Feature Covariance Matrix with Loan Default", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Covariance for Defaults (Not significant)

# %%
default_cov = cov_matrix["Default"].drop("Default").sort_values()
print(default_cov)
# Out:
# Income                  -1237.302790
# CreditScore                -1.739399
# MonthsEmployed             -1.080754
# Age                        -0.805790
# EmploymentCode             -0.015942
# EducationCode              -0.010123
# HasCoSignerCode            -0.006265
# HasDependentsCode          -0.005555
# HasMortgageCode            -0.003661
# LoanPurpose_Home           -0.002768
# LoanPurpose_Other           0.000350
# LoanPurpose_Education       0.000450
# LoanPurpose_Auto            0.000535
# DTIRatio                    0.001423
# LoanPurpose_Business        0.001433
# MaritalStatusCode           0.002066
# LoanTerm                    0.002961
# NumCreditLines              0.010138
# InterestRate                0.279110
# LoanAmount               1966.807516
# Name: Default, dtype: float64

# %%
plt.figure(figsize=(8, 5))
colors = ["#d73027" if x < 0 else "#4575b4" for x in default_cov]
default_cov.plot(kind="barh", color=colors)
plt.title("Linear Covariation of Features with Loan Default", fontsize=13)
plt.xlabel("Pearson Covariance Coefficient")
plt.tight_layout()
plt.show()

# %%
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio  ...  LoanPurpose_Other  \
# 0               4         15.23        36      0.44  ...                  1
# 1               1          4.81        60      0.68  ...                  1
# 2               3         21.17        24      0.31  ...                  0
# 3               3          7.07        24      0.23  ...                  0
# 4               4          6.51        48      0.73  ...                  0
#
#    MaritalStatusCode  EducationCode  EmploymentCode  HasMortgageCode  \
# 0                  2              1               3                1
# 1                  1              2               3                0
# 2                  2              2               0                1
# 3                  1              0               3                0
# 4                  2              1               0                0
#
#    HasDependentsCode  HasCoSignerCode       LTI  MonthlyDebtRatio  \
# 0                  1                1  0.588262       3153.113333
# 1                  0                1  2.467481       2857.813333
# 2                  1                0  1.534154       2175.373333
# 3                  0                0  1.412638        607.832500
# 4                  1                0  0.447179       1243.250833
#
#    InterestBurden
# 0       7704.4001
# 1       5985.5640
# 2      27349.0996
# 3       3167.2893
# 4        594.9489
#
# [5 rows x 25 columns]
